# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data_loader import load_train_data, load_test_data

train_df = load_train_data()
test_df = load_test_data()

print(train_df.shape)
print(test_df.shape)
# Out:
# (175341, 36)
# (82332, 36)

# %%
import src.model_loader

print(src.model_loader.__file__)
# Out:
# d:\ASR\Anomaly Detection System\src\model_loader.py

# %%
from src.model_loader import load_random_forest, load_label_encoders

# %%
print(dir(src.model_loader))
# Out:
# ['LABEL_ENCODERS', 'RANDOM_FOREST_MODEL', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'joblib', 'load_label_encoders', 'load_random_forest']

# %%
from src.model_loader import load_random_forest, load_label_encoders

rf = load_random_forest()
encoders = load_label_encoders()

print(type(rf))
print(type(encoders))
print(encoders.keys())
# Out:
# d:\ASR\Anomaly Detection System\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# <class 'dict'>
# dict_keys(['proto', 'service', 'state'])
# d:\ASR\Anomaly Detection System\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# d:\ASR\Anomaly Detection System\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from src.preprocessing import prepare_features, encode_features

X_test, y_test = prepare_features(test_df)
X_test = encode_features(X_test, encoders)

print(X_test.shape)
print(y_test.shape)
# Out:
# (82332, 34)
# (82332,)

# %%
from src.data_loader import load_test_data
from src.model_loader import load_random_forest, load_label_encoders
from src.preprocessing import prepare_features, encode_features
