# %% [markdown]
# # API Testing
# This notebook demonstrates how to test the prediction service using raw network flow data from the original dataset, rather than the preprocessed `X_test`.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Aryanshu\AppData\Local\Programs\Python\Python313\python.exe
